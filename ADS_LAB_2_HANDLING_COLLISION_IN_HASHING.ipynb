# %%
# Importing the required resources
import hashlib
from collections import defaultdict
import random
import string

# %% [markdown]
# ##### (i) The Python init Method - The init method is similar to constructors in C++ and Java. • It is run as soon as an object of a class is instantiated. • The method is useful to do any initialization you want to do with your object.
#
# ##### (ii) The Python self - Self represents the instance of the class. • We use self, since Python does not use the @ syntax to refer to instance attributes. • By using the “self” we can access the attributes and methods of the class in Python. • It binds the attributes with the given arguments.

# %% [markdown]
# ### Demonstration of Collision in Hash Tables
# Here, The hash function is key % size, which maps values to one of the available slots.
# Keys 10, 20, and 25 all hash to index 0, causing a collision.
# Keys 12 and 7 hash to index 2, causing another collision.
# Separate Chaining is used to handle collisions by storing multiple key-value pairs in a list at the same index.

# %% [markdown]
# ##### Example 1: Write a code to create a (i) Simple Hash Table (ii) Hash Table with Collision
# ##### Note: self.table: This is an instance variable (inside a class, typically a Hash Table class) that will store the actual data structure of the hash table.
# ##### [[] for _ in range(size)]:This is a list comprehension that creates a list of empty lists.
# ##### size: It is the total number of buckets (or "slots") in the hash table.
# ##### _: It is a throwaway variable name — it is used here because the index value itself is not needed.
# ##### For example, if size = 5, then:
# ##### self.table = [[ ], [ ], [ ], [ ], [ ]]

# %%
# Generation of Simple Hash Table with Collision
class HashTable:
    def __init__(self, size):
        self.size = size
        # self.table = [None] * size  # Empty hash table
        self.table = [[] for _ in range(size)]
        # Using separate chaining for collision handling

    def hash_function(self, key):
        """Simple hash function using modulo operation"""
        return key % self.size

    def insert(self, key, value):
        """Insert key-value pair into the hash table"""
        index = self.hash_function(key)
        self.table[index].append((key, value))
        # Append to handle collisions (Separate Chaining)
        print(f"Inserted ({key}, {value}) at index {index}")

    def display(self):
        """Display the hash table contents"""
        for i, bucket in enumerate(self.table):
            print(f"Index {i}: {bucket}")

# Create a Simple Hash Table with n slots and without collision
simple_hash_table = HashTable(7)  # Hash table with 7 slots
# Insert the elements
simple_hash_table.insert(14, "land")
simple_hash_table.insert(22, "Banana")
simple_hash_table.insert(2, "Cherry")
simple_hash_table.insert(12, "Date")
simple_hash_table.insert(10, "Elderberry")
simple_hash_table.insert(11, "Guava")
simple_hash_table.insert(13, "Blueberry")

# Display the Simple hash table with no collission
print("\n Simple Hash Table Content:")
simple_hash_table.display()

# Create a Hash Table with n slots
hash_table = HashTable(7)  # Hash table with 7 slots
# Inserting values, some keys will collide if they have the same remainders
# on divsion by the size = 7
print("\nInsert the values in the hash table to create collision:")
hash_table.insert(14, "land")
hash_table.insert(21, "Banana")
hash_table.insert(2, "Cherry")
hash_table.insert(12, "Date")
hash_table.insert(9, "Elderberry")
hash_table.insert(11, "Guava")
hash_table.insert(8, "Blueberry")
# Try more values to full utlization of Hash Table of size 7
hash_table.insert(10, "Apple")
hash_table.insert(20, "Muskmellon")
hash_table.insert(30, "Orange")
hash_table.insert(17, "Rasberry")
# Display the hash table showing collisions
print("\nHash Table Content showing collision:")
hash_table.display()
# Out:
# Inserted (14, land) at index 0
# Inserted (22, Banana) at index 1
# Inserted (2, Cherry) at index 2
# Inserted (12, Date) at index 5
# Inserted (10, Elderberry) at index 3
# Inserted (11, Guava) at index 4
# Inserted (13, Blueberry) at index 6
#
#  Simple Hash Table Content:
# Index 0: [(14, 'land')]
# Index 1: [(22, 'Banana')]
# Index 2: [(2, 'Cherry')]
# Index 3: [(10, 'Elderberry')]
# Index 4: [(11, 'Guava')]
# Index 5: [(12, 'Date')]
# Index 6: [(13, 'Blueberry')]
#
# Insert the values in the hash table to create collision:
# Inserted (14, land) at index 0
# Inserted (21, Banana) at index 0
# Inserted (2, Cherry) at index 2
# Inserted (12, Date) at index 5
# Inserted (9, Elderberry) at index 2
# Inserted (11, Guava) at index 4
# Inserted (8, Blueberry) at index 1
# Inserted (10, Apple) at index 3
# Inserted (20, Muskmellon) at index 6
# Inserted (30, Orange) at index 2
# Inserted (17, Rasberry) at index 3
#
# Hash Table Content showing collision:
# Index 0: [(14, 'land'), (21, 'Banana')]
# Index 1: [(8, 'Blueberry')]
# Index 2: [(2, 'Cherry'), (9, 'Elderberry'), (30, 'Orange')]
# Index 3: [(10, 'Apple'), (17, 'Rasberry')]
# Index 4: [(11, 'Guava')]
# Index 5: [(12, 'Date')]
# Index 6: [(20, 'Muskmellon')]

# %% [markdown]
# ##### Example 2: Demonstrate different types of types of Collision Handling Technique

# %% [markdown]
# ##### A. Open Addressing
# ##### 1. Linear Probing - Here if collision occurs, the next available slot in a sequential manner is used. Hash function: index = (hash(key) + i) % size, where i is incremented on each collision.

# %% [markdown]
# ##### self.table = [None] * size creates an empty list called self.table with a length equal to size. Each element of the list is initialized to None, representing empty slots in the hash table. This list will be used to store the actual data within the hash table.
# ##### i.e. When you create a new hash table object using this class, the __init__ method is called and it takes the desired size of the hash table as input. Stores this size within the object.Creates an empty list of the specified size to represent the hash table, with all slots initially empty.

# %%
# 1. Linear Probing
class LinearProbingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size  # Empty hash table

    def hash_function(self, key):
        return key % self.size  # Simple modulus hash function

    def insert(self, key, value):
        index = self.hash_function(key)
        original_index = index
        i = 0
        # Linear Probing: Find next available slot
        while self.table[index] is not None:
            print(f"Collision at index {index} for key {key}, trying next vacant slot...")
            i = i+1
            index = (original_index + i) % self.size  # important formula - Linear probing

        self.table[index] = (key, value)
        print(f"Inserted ({key}, {value}) at index {index}")

    def display(self):
        print("\nLinear Probing Hash Table:")
        for i, entry in enumerate(self.table):
            print(f"Index {i}: {entry}")
# Demonstration of Linear Probing
linear_hash_table = LinearProbingHashTable(7)
print("\n--- Linear Probing Demonstration ---")
linear_hash_table.insert(10, "Apple")  # 10 % 7 = 3
linear_hash_table.insert(20, "Banana") # 20 % 7 = 6
linear_hash_table.insert(30, "Cherry") # 30 % 7 = 2
linear_hash_table.insert(17, "Date")   # 17 % 7 = 3
print('Collision, resolved via linear probing')
print('and 17 is inserted at the vacant slot with index 4')
linear_hash_table.display()
print('\n\nCheck Linear Probing by adding 37 where 37 % 7 = 2, colliding with 30')
linear_hash_table.insert(37, "Guava")
print('Collision, resolved via linear probing')
print('and 37 is inserted at the vacant slot with index 5')
linear_hash_table.display()
print('\n\nAdd more elements say 48 to demonstarte how initial vacant slots are utlized')
linear_hash_table.insert(48, "Orange")
print('Collision, resolved via linear probing')
print('and 48 is inserted at the vacant slot with index 0')
linear_hash_table.display()
print('\n\nAdd more elements say 48 to demonstarte how initial vacant slots are utlized')
linear_hash_table.insert(19, "Watermellon")
print('Collision, resolved via linear probing')
print('and 19 is inserted at the vacant slot with index 1')
linear_hash_table.display()
# Out:
# --- Linear Probing Demonstration ---
# Inserted (10, Apple) at index 3
# Inserted (20, Banana) at index 6
# Inserted (30, Cherry) at index 2
# Collision at index 3 for key 17, trying next vacant slot...
# Inserted (17, Date) at index 4
# Collision, resolved via linear probing
# and 17 is inserted at the vacant slot with index 4
#
# Linear Probing Hash Table:
# Index 0: None
# Index 1: None
# Index 2: (30, 'Cherry')
# Index 3: (10, 'Apple')
# Index 4: (17, 'Date')
# Index 5: None
# Index 6: (20, 'Banana')
#
#
# Check Linear Probing by adding 37 where 37 % 7 = 2, colliding with 30
# Collision at index 2 for key 37, trying next vacant slot...
# Collision at index 3 for key 37, trying next vacant slot...
# Collision at index 4 for key 37, trying next vacant slot...
# Inserted (37, Guava) at index 5
# Collision, resolved via linear probing
# and 37 is inserted at the vacant slot with index 5
#
# Linear Probing Hash Table:
# Index 0: None
# Index 1: None
# Index 2: (30, 'Cherry')
# Index 3: (10, 'Apple')
# Index 4: (17, 'Date')
# Index 5: (37, 'Guava')
# Index 6: (20, 'Banana')
#
#
# Add more elements say 48 to demonstarte how initial vacant slots are utlized
# Collision at index 6 for key 48, trying next vacant slot...
# Inserted (48, Orange) at index 0
# Collision, resolved via linear probing
# and 48 is inserted at the vacant slot with index 0
#
# Linear Probing Hash Table:
# Index 0: (48, 'Orange')
# Index 1: None
# Index 2: (30, 'Cherry')
# Index 3: (10, 'Apple')
# Index 4: (17, 'Date')
# Index 5: (37, 'Guava')
# Index 6: (20, 'Banana')
#
#
# Add more elements say 48 to demonstarte how initial vacant slots are utlized
# Collision at index 5 for key 19, trying next vacant slot...
# Collision at index 6 for key 19, trying next vacant slot...
# Collision at index 0 for key 19, trying next vacant slot...
# Inserted (19, Watermellon) at index 1
# Collision, resolved via linear probing
# and 19 is inserted at the vacant slot with index 1
#
# Linear Probing Hash Table:
# Index 0: (48, 'Orange')
# Index 1: (19, 'Watermellon')
# Index 2: (30, 'Cherry')
# Index 3: (10, 'Apple')
# Index 4: (17, 'Date')
# Index 5: (37, 'Guava')
# Index 6: (20, 'Banana')

# %% [markdown]
# ##### 2. Quadratic Probing
# ##### Instead of checking the next slot sequentially, the next slot is determined using i^2.
# ##### Hash function: index = (hash(key) + i^2) % size.

# %%
# 2. Quadratic Probing
class QuadraticProbingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size  # Empty hash table

    def hash_function(self, key):
        return key % self.size  # Simple modulus hash function

    def insert(self, key, value):
        print('Inserted key =',key)
        index = self.hash_function(key)
        original_index = index
        print('original_index of ',key,'=',original_index)

        i = 0 # i is re-intialized for collision resolution
        # Quadratic Probing: Find next available slot
        while self.table[index] is not None:
            print(f"Collision at index {index} for key {key}, trying next slot using quadratic probing...")
            i = i+1
            print('i =',i)
            print('i square =',i**2)
            index = (original_index + i**2) % self.size  # Quadratic probing
            print('index = original_index + i square =',index)
        self.table[index] = (key, value)
        print(f"Inserted ({key}, {value}) at vacant index {index}")

    def display(self):
        print("\nQuadratic Probing Hash Table:")
        for i, entry in enumerate(self.table):
            print(f"Index {i}: {entry}")

# Demonstration of Quadratic Probing
quadratic_hash_table = QuadraticProbingHashTable(7) # numbered from 0 to 6
print("\n--- Quadratic Probing Demonstration ---")
quadratic_hash_table.insert(10, "Apple")  # 10 % 7 = 3
quadratic_hash_table.insert(20, "Banana") # 20 % 7 = 6
quadratic_hash_table.insert(30, "Cherry") # 30 % 7 = 2
quadratic_hash_table.insert(17, "Date")   # 17 % 7 = 3
print('Collision, resolved via quadratic probing\n')
quadratic_hash_table.display()
print('Collision, resolved via quadratic probing\n')
quadratic_hash_table.insert(27, "Elderberry") # 27 % 7 = 6 (Collision, resolved via quadratic probing)
quadratic_hash_table.display()
print('Collision, resolved via quadratic probing\n')
quadratic_hash_table.insert(44, "Papaya")
# 44 % 7 = 2 (Collision, resolved via quadratic probing)
quadratic_hash_table.display()
print('Collision, resolved via quadratic probing\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990226
# i square = 1599218175531076
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990227
# i square = 1599218255511529
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990228
# i square = 1599218335491984
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990229
# i square = 1599218415472441
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990230
# i square = 1599218495452900
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990231
# i square = 1599218575433361
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990232
# i square = 1599218655413824
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990233
# i square = 1599218735394289
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990234
# i square = 1599218815374756
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990235
# i square = 1599218895355225
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990236
# i square = 1599218975335696
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990237
# i square = 1599219055316169
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990238
# i square = 1599219135296644
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990239
# i square = 1599219215277121
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990240
# i square = 1599219295257600
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990241
# i square = 1599219375238081
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990242
# i square = 1599219455218564
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990243
# i square = 1599219535199049
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990244
# i square = 1599219615179536
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990245
# i square = 1599219695160025
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990246
# i square = 1599219775140516
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990247
# i square = 1599219855121009
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990248
# i square = 1599219935101504
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990249
# i square = 1599220015082001
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990250
# i square = 1599220095062500
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990251
# i square = 1599220175043001
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990252
# i square = 1599220255023504
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990253
# i square = 1599220335004009
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990254
# i square = 1599220414984516
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990255
# i square = 1599220494965025
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990256
# i square = 1599220574945536
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990257
# i square = 1599220654926049
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990258
# i square = 1599220734906564
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990259
# i square = 1599220814887081
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990260
# i square = 1599220894867600
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990261
# i square = 1599220974848121
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990262
# i square = 1599221054828644
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990263
# i square = 1599221134809169
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990264
# i square = 1599221214789696
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990265
# i square = 1599221294770225
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990266
# i square = 1599221374750756
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990267
# i square = 1599221454731289
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990268
# i square = 1599221534711824
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990269
# i square = 1599221614692361
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990270
# i square = 1599221694672900
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990271
# i square = 1599221774653441
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990272
# i square = 1599221854633984
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990273
# i square = 1599221934614529
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990274
# i square = 1599222014595076
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990275
# i square = 1599222094575625
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990276
# i square = 1599222174556176
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990277
# i square = 1599222254536729
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990278
# i square = 1599222334517284
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990279
# i square = 1599222414497841
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990280
# i square = 1599222494478400
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990281
# i square = 1599222574458961
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990282
# i square = 1599222654439524
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990283
# i square = 1599222734420089
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990284
# i square = 1599222814400656
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990285
# i square = 1599222894381225
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990286
# i square = 1599222974361796
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990287
# i square = 1599223054342369
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990288
# i square = 1599223134322944
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990289
# i square = 1599223214303521
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990290
# i square = 1599223294284100
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990291
# i square = 1599223374264681
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990292
# i square = 1599223454245264
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990293
# i square = 1599223534225849
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990294
# i square = 1599223614206436
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990295
# i square = 1599223694187025
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990296
# i square = 1599223774167616
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990297
# i square = 1599223854148209
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990298
# i square = 1599223934128804
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990299
# i square = 1599224014109401
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990300
# i square = 1599224094090000
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990301
# i square = 1599224174070601
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990302
# i square = 1599224254051204
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990303
# i square = 1599224334031809
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990304
# i square = 1599224414012416
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990305
# i square = 1599224493993025
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990306
# i square = 1599224573973636
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990307
# i square = 1599224653954249
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990308
# i square = 1599224733934864
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990309
# i square = 1599224813915481
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990310
# i square = 1599224893896100
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990311
# i square = 1599224973876721
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990312
# i square = 1599225053857344
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990313
# i square = 1599225133837969
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990314
# i square = 1599225213818596
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990315
# i square = 1599225293799225
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990316
# i square = 1599225373779856
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990317
# i square = 1599225453760489
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990318
# i square = 1599225533741124
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990319
# i square = 1599225613721761
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990320
# i square = 1599225693702400
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990321
# i square = 1599225773683041
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990322
# i square = 1599225853663684
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990323
# i square = 1599225933644329
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990324
# i square = 1599226013624976
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990325
# i square = 1599226093605625
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990326
# i square = 1599226173586276
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990327
# i square = 1599226253566929
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990328
# i square = 1599226333547584
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990329
# i square = 1599226413528241
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990330
# i square = 1599226493508900
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990331
# i square = 1599226573489561
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990332
# i square = 1599226653470224
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990333
# i square = 1599226733450889
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990334
# i square = 1599226813431556
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990335
# i square = 1599226893412225
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990336
# i square = 1599226973392896
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990337
# i square = 1599227053373569
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990338
# i square = 1599227133354244
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990339
# i square = 1599227213334921
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990340
# i square = 1599227293315600
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990341
# i square = 1599227373296281
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990342
# i square = 1599227453276964
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990343
# i square = 1599227533257649
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990344
# i square = 1599227613238336
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990345
# i square = 1599227693219025
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990346
# i square = 1599227773199716
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990347
# i square = 1599227853180409
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990348
# i square = 1599227933161104
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990349
# i square = 1599228013141801
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990350
# i square = 1599228093122500
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990351
# i square = 1599228173103201
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990352
# i square = 1599228253083904
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990353
# i square = 1599228333064609
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990354
# i square = 1599228413045316
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990355
# i square = 1599228493026025
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990356
# i square = 1599228573006736
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990357
# i square = 1599228652987449
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990358
# i square = 1599228732968164
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990359
# i square = 1599228812948881
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990360
# i square = 1599228892929600
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990361
# i square = 1599228972910321
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990362
# i square = 1599229052891044
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990363
# i square = 1599229132871769
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990364
# i square = 1599229212852496
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990365
# i square = 1599229292833225
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990366
# i square = 1599229372813956
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990367
# i square = 1599229452794689
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990368
# i square = 1599229532775424
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990369
# i square = 1599229612756161
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990370
# i square = 1599229692736900
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990371
# i square = 1599229772717641
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990372
# i square = 1599229852698384
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990373
# i square = 1599229932679129
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990374
# i square = 1599230012659876
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990375
# i square = 1599230092640625
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990376
# i square = 1599230172621376
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990377
# i square = 1599230252602129
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990378
# i square = 1599230332582884
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990379
# i square = 1599230412563641
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990380
# i square = 1599230492544400
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990381
# i square = 1599230572525161
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990382
# i square = 1599230652505924
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990383
# i square = 1599230732486689
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990384
# i square = 1599230812467456
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990385
# i square = 1599230892448225
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990386
# i square = 1599230972428996
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990387
# i square = 1599231052409769
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990388
# i square = 1599231132390544
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990389
# i square = 1599231212371321
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990390
# i square = 1599231292352100
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990391
# i square = 1599231372332881
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990392
# i square = 1599231452313664
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990393
# i square = 1599231532294449
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990394
# i square = 1599231612275236
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990395
# i square = 1599231692256025
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990396
# i square = 1599231772236816
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990397
# i square = 1599231852217609
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990398
# i square = 1599231932198404
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990399
# i square = 1599232012179201
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990400
# i square = 1599232092160000
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990401
# i square = 1599232172140801
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990402
# i square = 1599232252121604
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990403
# i square = 1599232332102409
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990404
# i square = 1599232412083216
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990405
# i square = 1599232492064025
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990406
# i square = 1599232572044836
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990407
# i square = 1599232652025649
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990408
# i square = 1599232732006464
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990409
# i square = 1599232811987281
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990410
# i square = 1599232891968100
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990411
# i square = 1599232971948921
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990412
# i square = 1599233051929744
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990413
# i square = 1599233131910569
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990414
# i square = 1599233211891396
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990415
# i square = 1599233291872225
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990416
# i square = 1599233371853056
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990417
# i square = 1599233451833889
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990418
# i square = 1599233531814724
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990419
# i square = 1599233611795561
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990420
# i square = 1599233691776400
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990421
# i square = 1599233771757241
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990422
# i square = 1599233851738084
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990423
# i square = 1599233931718929
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990424
# i square = 1599234011699776
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990425
# i square = 1599234091680625
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990426
# i square = 1599234171661476
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990427
# i square = 1599234251642329
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990428
# i square = 1599234331623184
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990429
# i square = 1599234411604041
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990430
# i square = 1599234491584900
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990431
# i square = 1599234571565761
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990432
# i square = 1599234651546624
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990433
# i square = 1599234731527489
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990434
# i square = 1599234811508356
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990435
# i square = 1599234891489225
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990436
# i square = 1599234971470096
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990437
# i square = 1599235051450969
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990438
# i square = 1599235131431844
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990439
# i square = 1599235211412721
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990440
# i square = 1599235291393600
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990441
# i square = 1599235371374481
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990442
# i square = 1599235451355364
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990443
# i square = 1599235531336249
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990444
# i square = 1599235611317136
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990445
# i square = 1599235691298025
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990446
# i square = 1599235771278916
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990447
# i square = 1599235851259809
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990448
# i square = 1599235931240704
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990449
# i square = 1599236011221601
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990450
# i square = 1599236091202500
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990451
# i square = 1599236171183401
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990452
# i square = 1599236251164304
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990453
# i square = 1599236331145209
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990454
# i square = 1599236411126116
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990455
# i square = 1599236491107025
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990456
# i square = 1599236571087936
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990457
# i square = 1599236651068849
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990458
# i square = 1599236731049764
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990459
# i square = 1599236811030681
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990460
# i square = 1599236891011600
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990461
# i square = 1599236970992521
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990462
# i square = 1599237050973444
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990463
# i square = 1599237130954369
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990464
# i square = 1599237210935296
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990465
# i square = 1599237290916225
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990466
# i square = 1599237370897156
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990467
# i square = 1599237450878089
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990468
# i square = 1599237530859024
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990469
# i square = 1599237610839961
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990470
# i square = 1599237690820900
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990471
# i square = 1599237770801841
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990472
# i square = 1599237850782784
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990473
# i square = 1599237930763729
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990474
# i square = 1599238010744676
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990475
# i square = 1599238090725625
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990476
# i square = 1599238170706576
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990477
# i square = 1599238250687529
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990478
# i square = 1599238330668484
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990479
# i square = 1599238410649441
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990480
# i square = 1599238490630400
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990481
# i square = 1599238570611361
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990482
# i square = 1599238650592324
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990483
# i square = 1599238730573289
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990484
# i square = 1599238810554256
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990485
# i square = 1599238890535225
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990486
# i square = 1599238970516196
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990487
# i square = 1599239050497169
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990488
# i square = 1599239130478144
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990489
# i square = 1599239210459121
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990490
# i square = 1599239290440100
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990491
# i square = 1599239370421081
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990492
# i square = 1599239450402064
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990493
# i square = 1599239530383049
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990494
# i square = 1599239610364036
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990495
# i square = 1599239690345025
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990496
# i square = 1599239770326016
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990497
# i square = 1599239850307009
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990498
# i square = 1599239930288004
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990499
# i square = 1599240010269001
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990500
# i square = 1599240090250000
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990501
# i square = 1599240170231001
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990502
# i square = 1599240250212004
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990503
# i square = 1599240330193009
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990504
# i square = 1599240410174016
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990505
# i square = 1599240490155025
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990506
# i square = 1599240570136036
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990507
# i square = 1599240650117049
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990508
# i square = 1599240730098064
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990509
# i square = 1599240810079081
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990510
# i square = 1599240890060100
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990511
# i square = 1599240970041121
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990512
# i square = 1599241050022144
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990513
# i square = 1599241130003169
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990514
# i square = 1599241209984196
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990515
# i square = 1599241289965225
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990516
# i square = 1599241369946256
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990517
# i square = 1599241449927289
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990518
# i square = 1599241529908324
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990519
# i square = 1599241609889361
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990520
# i square = 1599241689870400
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990521
# i square = 1599241769851441
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990522
# i square = 1599241849832484
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990523
# i square = 1599241929813529
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990524
# i square = 1599242009794576
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990525
# i square = 1599242089775625
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990526
# i square = 1599242169756676
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990527
# i square = 1599242249737729
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990528
# i square = 1599242329718784
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39990529
# i square = 1599242409699841
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39990530
# i square = 1599242489680900
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39990531
# i square = 1599242569661961
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39990532
# i square = 1599242649643024
# index = original_index + i square = 3
# ...
# i = 39991373
# i square = 1599309914425129
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991374
# i square = 1599309994407876
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991375
# i square = 1599310074390625
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991376
# i square = 1599310154373376
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991377
# i square = 1599310234356129
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991378
# i square = 1599310314338884
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991379
# i square = 1599310394321641
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991380
# i square = 1599310474304400
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991381
# i square = 1599310554287161
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991382
# i square = 1599310634269924
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991383
# i square = 1599310714252689
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991384
# i square = 1599310794235456
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991385
# i square = 1599310874218225
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991386
# i square = 1599310954200996
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991387
# i square = 1599311034183769
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991388
# i square = 1599311114166544
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991389
# i square = 1599311194149321
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991390
# i square = 1599311274132100
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991391
# i square = 1599311354114881
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991392
# i square = 1599311434097664
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991393
# i square = 1599311514080449
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991394
# i square = 1599311594063236
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991395
# i square = 1599311674046025
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991396
# i square = 1599311754028816
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991397
# i square = 1599311834011609
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991398
# i square = 1599311913994404
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991399
# i square = 1599311993977201
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991400
# i square = 1599312073960000
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991401
# i square = 1599312153942801
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991402
# i square = 1599312233925604
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991403
# i square = 1599312313908409
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991404
# i square = 1599312393891216
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991405
# i square = 1599312473874025
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991406
# i square = 1599312553856836
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991407
# i square = 1599312633839649
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991408
# i square = 1599312713822464
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991409
# i square = 1599312793805281
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991410
# i square = 1599312873788100
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991411
# i square = 1599312953770921
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991412
# i square = 1599313033753744
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991413
# i square = 1599313113736569
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991414
# i square = 1599313193719396
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991415
# i square = 1599313273702225
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991416
# i square = 1599313353685056
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991417
# i square = 1599313433667889
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991418
# i square = 1599313513650724
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991419
# i square = 1599313593633561
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991420
# i square = 1599313673616400
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991421
# i square = 1599313753599241
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991422
# i square = 1599313833582084
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991423
# i square = 1599313913564929
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991424
# i square = 1599313993547776
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991425
# i square = 1599314073530625
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991426
# i square = 1599314153513476
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991427
# i square = 1599314233496329
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991428
# i square = 1599314313479184
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991429
# i square = 1599314393462041
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991430
# i square = 1599314473444900
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991431
# i square = 1599314553427761
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991432
# i square = 1599314633410624
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991433
# i square = 1599314713393489
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991434
# i square = 1599314793376356
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991435
# i square = 1599314873359225
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991436
# i square = 1599314953342096
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991437
# i square = 1599315033324969
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991438
# i square = 1599315113307844
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991439
# i square = 1599315193290721
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991440
# i square = 1599315273273600
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991441
# i square = 1599315353256481
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991442
# i square = 1599315433239364
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991443
# i square = 1599315513222249
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991444
# i square = 1599315593205136
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991445
# i square = 1599315673188025
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991446
# i square = 1599315753170916
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991447
# i square = 1599315833153809
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991448
# i square = 1599315913136704
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991449
# i square = 1599315993119601
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991450
# i square = 1599316073102500
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991451
# i square = 1599316153085401
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991452
# i square = 1599316233068304
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991453
# i square = 1599316313051209
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991454
# i square = 1599316393034116
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991455
# i square = 1599316473017025
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991456
# i square = 1599316552999936
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991457
# i square = 1599316632982849
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991458
# i square = 1599316712965764
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991459
# i square = 1599316792948681
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991460
# i square = 1599316872931600
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991461
# i square = 1599316952914521
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991462
# i square = 1599317032897444
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991463
# i square = 1599317112880369
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991464
# i square = 1599317192863296
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991465
# i square = 1599317272846225
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991466
# i square = 1599317352829156
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991467
# i square = 1599317432812089
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991468
# i square = 1599317512795024
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991469
# i square = 1599317592777961
# index = original_index + i square = 2
# Collision at index 2 for key 44, trying next slot using quadratic probing...
# i = 39991470
# i square = 1599317672760900
# index = original_index + i square = 3
# Collision at index 3 for key 44, trying next slot using quadratic probing...
# i = 39991471
# i square = 1599317752743841
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991472
# i square = 1599317832726784
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991473
# i square = 1599317912709729
# index = original_index + i square = 4
# Collision at index 4 for key 44, trying next slot using quadratic probing...
# i = 39991474
# i square = 1599317992692676
# index = original_index + i square = 6
# Collision at index 6 for key 44, trying next slot using quadratic probing...
# i = 39991475
# i square = 1599318072675625
# index = original_index + i square = 3

# %% [markdown]
# 3. Double Hashing-
# ##### It uses a secondary hash function to determine the probe sequence as follows:
# ##### Primary Hash Function: index = key % size
# ##### Secondary Hash Function: step_size = secondary_hash(key),where
# ##### secondary_hash(key) = prime - (key % prime),and prime is a number smaller than the table size.
# ##### Probing Sequence: index = (primary_hash + i * step_size) % size,where i increases on collision.
# ##### This ensures better distribution and avoids clustering.

# %%
class DoubleHashingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size  # Empty hash table
        self.prime = self.get_smaller_prime()
        # Prime number for secondary hashing will be received from the next functions
        print('self.prime =', self.prime)

    def get_smaller_prime(self):
        """Finds the largest prime smaller than table size for secondary hashing"""
        for num in range(self.size - 1, 1, -1):
          # range(start, stop, step)
            if self.is_prime(num):
                return num
        return 3  # Default to 3 if no prime found

    def is_prime(self, num):
        print('num =',num)
        """Check if a number is prime"""
        if num < 2:
            return False
        for i in range(2, int(num ** 0.5) + 1):
          # Using Sieve Principal - we need not check for the factors upto n, instead we can check upto n/2
            if num % i == 0:
                return False
        return True

    def primary_hash(self, key):
        """Primary hash function"""
        return key % self.size

    def secondary_hash(self, key):
        """Secondary hash function for step size"""
        return self.prime - (key % self.prime)

    def insert(self, key, value):
        """Insert a key-value pair using double hashing"""
        print('key =',key)
        index = self.primary_hash(key)
        print('index =',index)
        print('self.prime = ', self.prime)
        print('self.prime - (key % self.prime) =',self.prime - (key % self.prime))
        print('self.secondary_hash(key) = ', self.secondary_hash(key))
        step_size = self.secondary_hash(key)
        print('step_size =',step_size)
        original_index = index
        print('original_index =',original_index)
        i = 0

        # Double Hashing: Find next available slot
        while self.table[index] is not None:
            print(f"Collision at index {index} for key {key}, using double hashing...")
            i += 1
            print('i = ',i)
            index = (original_index + i * step_size) % self.size
            print('original_index =',original_index)
            print('step_size =',step_size)
            print('index =',index)
        self.table[index] = (key, value)
        print(f"Inserted ({key}, {value}) at index {index}")

    def display(self):
        """Display the hash table"""
        print("\nDouble Hashing Hash Table:")
        for i, entry in enumerate(self.table):
            print(f"Index {i}: {entry}")

# Demonstration of Double Hashing
double_hash_table = DoubleHashingHashTable(7)
print('self.size =',7)

print("\n--- Double Hashing Demonstration ---")
double_hash_table.insert(10, "Apple")  # 10 % 7 = 3
double_hash_table.insert(20, "Banana") # 20 % 7 = 6
double_hash_table.insert(30, "Cherry") # 30 % 7 = 2
double_hash_table.insert(17, "Date")   # 17 % 7 = 3 (Collision, resolved via double hashing)
double_hash_table.insert(27, "Elderberry") # 27 % 7 = 6 (Collision, resolved via double hashing)
double_hash_table.display()
# Out:
# num = 6
# num = 5
# self.prime = 5
# self.size = 7
#
# --- Double Hashing Demonstration ---
# key = 10
# index = 3
# self.prime =  5
# self.prime - (key % self.prime) = 5
# self.secondary_hash(key) =  5
# step_size = 5
# original_index = 3
# Inserted (10, Apple) at index 3
# key = 20
# index = 6
# self.prime =  5
# self.prime - (key % self.prime) = 5
# self.secondary_hash(key) =  5
# step_size = 5
# original_index = 6
# Inserted (20, Banana) at index 6
# key = 30
# index = 2
# self.prime =  5
# self.prime - (key % self.prime) = 5
# self.secondary_hash(key) =  5
# step_size = 5
# original_index = 2
# Inserted (30, Cherry) at index 2
# key = 17
# index = 3
# self.prime =  5
# self.prime - (key % self.prime) = 3
# self.secondary_hash(key) =  3
# step_size = 3
# original_index = 3
# Collision at index 3 for key 17, using double hashing...
# i =  1
# original_index = 3
# step_size = 3
# index = 6
# Collision at index 6 for key 17, using double hashing...
# i =  2
# original_index = 3
# step_size = 3
# index = 2
# Collision at index 2 for key 17, using double hashing...
# i =  3
# original_index = 3
# step_size = 3
# index = 5
# Inserted (17, Date) at index 5
# key = 27
# index = 6
# self.prime =  5
# self.prime - (key % self.prime) = 3
# self.secondary_hash(key) =  3
# step_size = 3
# original_index = 6
# Collision at index 6 for key 27, using double hashing...
# i =  1
# original_index = 6
# step_size = 3
# index = 2
# Collision at index 2 for key 27, using double hashing...
# i =  2
# original_index = 6
# step_size = 3
# index = 5
# Collision at index 5 for key 27, using double hashing...
# i =  3
# original_index = 6
# step_size = 3
# index = 1
# Inserted (27, Elderberry) at index 1
#
# Double Hashing Hash Table:
# Index 0: None
# Index 1: (27, 'Elderberry')
# Index 2: (30, 'Cherry')
# Index 3: (10, 'Apple')
# Index 4: None
# Index 5: (17, 'Date')
# Index 6: (20, 'Banana')
